# %%
# %pip install --quiet numpy==1.23.5 tensorflow==2.11.0

import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# WARNING: Ignoring invalid distribution ~hromadb (c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.11.0 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow==2.11.0
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 6 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\__init__.py:55
#      53 from tensorflow._api.v2 import autograph
#      54 from tensorflow._api.v2 import bitwise
# ---> 55 from tensorflow._api.v2 import compat
#      56 from tensorflow._api.v2 import config
#      57 from tensorflow._api.v2 import data
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:47
#      45 from tensorflow._api.v2.compat.v1 import layers
#      46 from tensorflow._api.v2.compat.v1 import linalg
# ---> 47 from tensorflow._api.v2.compat.v1 import lite
#      48 from tensorflow._api.v2.compat.v1 import logging
#      49 from tensorflow._api.v2.compat.v1 import lookup
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\v1\lite\__init__.py:9
#       6 import sys as _sys
#       8 from tensorflow._api.v2.compat.v1.lite import constants
# ----> 9 from tensorflow._api.v2.compat.v1.lite import experimental
#      10 from tensorflow.lite.python.convert import OpsSet # line: 153
#      11 from tensorflow.lite.python.convert import toco_convert # line: 937
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\__init__.py:8
#       3 """Public API for tf._api.v2.lite.experimental namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.lite.experimental import authoring
#       9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer # line: 35
#      10 from tensorflow.lite.python.interpreter import OpResolverType # line: 315
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\authoring\__init__.py:8
#       3 """Public API for tf._api.v2.lite.experimental.authoring namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.lite.python.authoring.authoring import compatible # line: 263
#      10 from tensorflow.python.util import module_wrapper as _module_wrapper
#      12 if not isinstance(_sys.modules[__name__], _module_wrapper.TFModuleWrapper):
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\authoring\authoring.py:42
#      40 from tensorflow.compiler.mlir.lite.metrics import converter_error_data_pb2
#      41 # pylint: disable=g-import-not-at-top
# ---> 42 from tensorflow.lite.python import convert
#      43 from tensorflow.lite.python import lite
#      44 from tensorflow.python.util.tf_export import tf_export as _tf_export
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\convert.py:31
#      29 from tensorflow.compiler.mlir.quantization.stablehlo import quantization_options_pb2 as quant_opts_pb2
#      30 from tensorflow.lite.python import lite_constants
# ---> 31 from tensorflow.lite.python import util
#      32 from tensorflow.lite.python.convert_phase import Component
#      33 from tensorflow.lite.python.convert_phase import convert_phase
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\util.py:53
#      49 # Jax functions used by TFLite
#      50 # pylint: disable=g-import-not-at-top
#      51 # pylint: disable=unused-import
#      52 try:
# ---> 53   from jax import jit as _jit
#      54 except ImportError:
#      55   _jit = None
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\jax\__init__.py:37
#      34 del _cloud_tpu_init
#      36 # Force early import, allowing use of `jax.core` after importing `jax`.
# ---> 37 import jax.core as _core
#      38 del _core
#      40 # Note: import <name> as <name> is required for names to be exported.
#      41 # See PEP 484 & https://github.com/jax-ml/jax/issues/7570
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\jax\core.py:18
#       1 # Copyright 2022 The JAX Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      15 # Note: import <name> as <name> is required for names to be exported.
#      16 # See PEP 484 & https://github.com/jax-ml/jax/issues/7570
# ---> 18 from jax._src.core import (
#      19   AbstractToken as AbstractToken,
#      20   AbstractValue as AbstractValue,
#      21   Atom as Atom,
#      22   CallPrimitive as CallPrimitive,
#      23   DebugInfo as DebugInfo,
#      24   DShapedArray as DShapedArray,
#      25   DropVar as DropVar,
#      26   Effect as Effect,
#      27   Effects as Effects,
#      28   get_opaque_trace_state as get_opaque_trace_state,
#      29   InconclusiveDimensionOperation as InconclusiveDimensionOperation,
#      30   JaxprPpContext as JaxprPpContext,
#      31   JaxprPpSettings as JaxprPpSettings,
#      32   JaxprTypeError as JaxprTypeError,
#      33   nonempty_axis_env as nonempty_axis_env_DO_NOT_USE,  # noqa: F401
#      34   OutputType as OutputType,
#      35   ParamDict as ParamDict,
#      36   ShapedArray as ShapedArray,
#      37   Trace as Trace,
#      38   Tracer as Tracer,
#      39   unsafe_am_i_under_a_jit as unsafe_am_i_under_a_jit_DO_NOT_USE,  # noqa: F401
#      40   unsafe_am_i_under_a_vmap as unsafe_am_i_under_a_vmap_DO_NOT_USE,  # noqa: F401
#      41   unsafe_get_axis_names as unsafe_get_axis_names_DO_NOT_USE,  # noqa: F401
#      42   UnshapedArray as UnshapedArray,
#      43   Value as Value,
#      44   abstract_token as abstract_token,
#      45   aval_mapping_handlers as aval_mapping_handlers,
#      46   call as call,
#      47   call_impl as call_impl,
#      48   check_jaxpr as check_jaxpr,
#      49   concrete_or_error as concrete_or_error,
#      50   concretization_function_error as concretization_function_error,
#      51   custom_typechecks as custom_typechecks,
#      52   ensure_compile_time_eval as ensure_compile_time_eval,
#      53   eval_context as eval_context,
#      54   eval_jaxpr as eval_jaxpr,
#      55   find_top_trace as find_top_trace,
#      56   gensym as gensym,
#      57   get_aval as get_aval,
#      58   is_concrete as is_concrete,
#      59   is_constant_dim as is_constant_dim,
#      60   is_constant_shape as is_constant_shape,
#      61   jaxprs_in_params as jaxprs_in_params,
#      62   literalable_types as literalable_types,
#      63   mapped_aval as mapped_aval,
#      64   max_dim as max_dim,
#      65   min_dim as min_dim,
#      66   new_jaxpr_eqn as new_jaxpr_eqn,
#      67   no_axis_name as no_axis_name,
#      68   no_effects as no_effects,
#      69   primal_dtype_to_tangent_dtype as primal_dtype_to_tangent_dtype,
#      70   pytype_aval_mappings as pytype_aval_mappings,
#      71   set_current_trace as set_current_trace,
#      72   subjaxprs as subjaxprs,
#      73   take_current_trace as take_current_trace,
#      74   trace_ctx as trace_ctx,
#      75   TraceTag as TraceTag,
#      76   traverse_jaxpr_params as traverse_jaxpr_params,
#      77   unmapped_aval as unmapped_aval,
#      78   valid_jaxtype as valid_jaxtype,
#      79 )
#      82 from jax._src import core as _src_core
#      83 _deprecations = {
#      84     # Added 2024-12-11
#      85     "axis_frame": ("jax.core.axis_frame is deprecated.", _src_core.axis_frame),
#    (...)
#     143     "used_axis_names_jaxpr": ("jax.core.used_axis_names_jaxpr was removed in JAX v0.6.0.", None),
#     144 }
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\jax\_src\core.py:38
#      35 import numpy as np
#      37 from jax._src import deprecations
# ---> 38 from jax._src import dtypes
#      39 from jax._src import config
#      40 from jax._src import effects
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\jax\_src\dtypes.py:518
#     511 # We add the StringDType only to `_jax_dtype_set` but not to `_jax_types` and
#     512 # `_dtype_kinds`. This is because, in spite of a very similar sounding name,
#     513 # `_jax_types` is only meant for the promotion related logic, and StringDType
#     514 # does not participate in promotions at the moment. Similarly, `_dtype_kinds` is
#     515 # only meant for the `jnp.isdtype` and we want to be conservative and not allow
#     516 # StringDType to be used in there.
#     517 _string_types: list[JAXType] = []
# --> 518 if hasattr(np.dtypes, 'StringDType'):
#     519   _string_types: list[JAXType] = [np.dtypes.StringDType()]  # type: ignore
#     521 _jax_dtype_set = {
#     522     float0,
#     523     *_bool_types,
#    (...)
#     527     *_string_types,
#     528 }
#
# File c:\Users\AJIT ASHWATH R\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'dtypes'

# %%
DATA_DIR = '../data/processed'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    os.path.join(DATA_DIR, 'train'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(DATA_DIR, 'validation'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)

print(f"Training samples: {train_generator.samples}")
print(f"Validation samples: {val_generator.samples}")
print(f"Class indices: {train_generator.class_indices}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3956841938.py in <cell line: 0>()
# ----> 1 train_generator = train_datagen.flow_from_directory(
#       2     os.path.join(DATA_DIR, 'train'),
#       3     target_size=IMG_SIZE,
#       4     batch_size=BATCH_SIZE,
#       5     class_mode='binary',
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     451         if not classes:
#     452             classes = []
# --> 453             for subdir in sorted(os.listdir(directory)):
#     454                 if os.path.isdir(os.path.join(directory, subdir)):
#     455                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/processed/train'

# %%
sample_batch, sample_labels = next(train_generator)

plt.figure(figsize=(15, 10))
for i in range(min(16, len(sample_batch))):
    plt.subplot(4, 4, i+1)
    plt.imshow(sample_batch[i])
    label = "Defect" if sample_labels[i] == 0 else "Pass"
    plt.title(f"{label}")
    plt.axis('off')
plt.tight_layout()
plt.show()

print("Data pipeline ready!")
